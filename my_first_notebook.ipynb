# %% [markdown]
# Q. What is the difference between hardware and software?
# A.
# Hardware : Hardware is a physical component of an computer. It exists in physical form which we can feel it by touch and see.
# example : mouse, keyboard, cpu, ram etc.
#
# Software : Software is set of instructions or commands packaged together as an installer/executable. Software uses hardware to perform tasks.
# example : OS, MS office, VS code etc.
